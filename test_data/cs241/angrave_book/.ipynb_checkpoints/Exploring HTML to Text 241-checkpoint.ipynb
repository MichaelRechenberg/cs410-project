# %%
# Experimenting with turning html -> a text file we can feed to MeTA
from bs4 import BeautifulSoup

with open('processcontrolpart1waitmacrosusingsignals.html') as f:
    soup = BeautifulSoup(f, "html5lib")

# %%
#<title>
#<all h1, h2, h3...>
#<span>?
#<p>
#<pre>
#<code>

tags_we_want = ['title', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'span', 'p', 'pre', 'code']

for tag in tags_we_want:
    print("Printing Info for Tag {0}\n".format(tag))
    tags = soup.find_all(tag)
    for entry in tags:
        print(entry.text)
    print()
# Out:
# Printing Info for Tag title
#
# Process Control, Part 1: Wait macros, using signals
#
# Printing Info for Tag h1
#
#
# Printing Info for Tag h2
#
# Can I find out the exit value of my child?
# Can I pause my child?
# How do I kill/stop/suspend my child from C?
# How can I detect "CTRL-C" and clean up gracefully?
#
# Printing Info for Tag h3
#
# Process Control, Part 1: Wait macros, using signals
#
# Printing Info for Tag h4
#
#
# Printing Info for Tag h5
#
#
# Printing Info for Tag h6
#
#
# Printing Info for Tag span
#
# Process Control, Part 1: Wait macros, using signals
#
# Printing Info for Tag p
#
# You can find the lowest 8 bits of the child's exit value (the return value of main() or value included in exit()): Use the "Wait macros" - typically you will use "WIFEXITED" and "WEXITSTATUS" . See wait/waitpid man page for more information).
# Yes ! You can temporarily pause a running process by sending it a SIGSTOP signal.
# ...
